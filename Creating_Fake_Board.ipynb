# %%
b = int(input("Enter board size : "))
count  =  0
while b != count :
    
    
    print (" ---"*b)
    print ("|   "*(b+1))
    print (" ---"*b)
    count = count + 1
# Out:
# Enter board size : 10
#  --- --- --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- --- --- ---
#  --- --- --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- --- --- ---
#  --- --- --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- --- --- ---
#  --- --- --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- --- --- ---
#  --- --- --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- --- --- ---
#  --- --- --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- --- --- ---
#  --- --- --- --- --- --- --- --- --- ---
# |   |   |   |   |   |   |   |   |   |   |
#  --- --- --- --- --- --- --- --- --- ---
#  --- --- --- --- --- --- --- --- --- ---
# ...
