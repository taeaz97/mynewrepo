# %% [markdown]
# # PROJECT
# ### Dataset for Hotel Booking
# A dataset on hotel booking of a company comparing between two hotels which are city hotel and resort hotel. <br>
# The data of guest booking and both of hotel from July 2015 to August 2017.<br>
# Therefore, in pandas the data only for 2016 are used to observe the hotel booking of these two hotel from <br>
# January to December of 2016.<br>
# The data is *hotel_booking.csv* source from *kaggle*.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
#importing pandas , numpy , matplotlib.pylot to run the code

# %%
hotel = pd.read_csv('hotel_booking.csv')#set hotel as the main dataFrame

# %% [markdown]
# #### Manual Filtering
# In this notebook, I choose to only observe the data from the perspective of the year for 2016.<br>
# Therefore, from the main dataframe *hotel* , I filter to make new dataframe which is *hotel_2016*.<br>

# %%
hotel_2016 = hotel[hotel['arrival_date_year']==2016]

# %%
hotel_2016
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 3738    Resort Hotel            0        109               2016
# 3739    Resort Hotel            0        109               2016
# 3740    Resort Hotel            1          2               2016
# 3741    Resort Hotel            0         88               2016
# 3742    Resort Hotel            1         20               2016
# ...              ...          ...        ...                ...
# 104142    City Hotel            0         17               2016
# 104145    City Hotel            0        177               2016
# 104147    City Hotel            0        107               2016
# 104216    City Hotel            0        310               2016
# 104219    City Hotel            0        310               2016
#
#        arrival_date_month  arrival_date_week_number  \
# 3738              January                         1
# 3739              January                         1
# ...

# %% [markdown]
# >FUNCTIONS
# ---
# In this **checking()** function, we can check the dataframe that we created. <br>
# From shape, list of columns, data types for each column, index of the dataframe, the summary of the dataframe.<br>
# So, the user choose from number 1 to number 5 according to the code to get what the user desired from the summary .<br>
# This can be done so the user can understand about the dataframe before starting to explore the data.

# %%
def checking():
    while True:
        try:
            input_cond = int(input( " Choose 1:shape\n Choose 2:columns\n Choose 3:data types\n Choose 4:index\n Choose 5:describe"))
            if input_cond == 1:
                print ("These are the rows and columns of the DataFrame ",hotel_2016.shape)
            if input_cond == 2:
                print ("These are the list of columns for the DataFrame \n \n",hotel_2016.columns)
            if input_cond == 3:
                print ("These are the data types for the columns in DataFrame \n\n",hotel_2016.dtypes)
            if input_cond == 4:
                print( "The DataFrame is currently using this as index\n\n",hotel_2016.index) 
            if input_cond == 5:
                print("These are the summary of the DataFrame\n\n",hotel_2016.describe())
            #else:
                #print("Please enter number from 1 to 5")
                #continue
        except Exception as ex:
            print("Please enter number from 1 to 5")
            continue #to reset the loop by asking the input value again
        else:
            print("Yes, you got the summary!")
            break

# %%
# can use it for all dataframe but assign to hotel_2016,
# then reassign hotel_2016 to the desired dataframe
# hotel1 = hotel_2016, if want to use the function and same for all functions

# %%
checking()
# Out:
#  Choose 1:shape
#  Choose 2:columns
#  Choose 3:data types
#  Choose 4:index
#  Choose 5:describe1
# These are the rows and columns of the DataFrame  (56707, 36)
# Yes, you got the summary!

# %%
checking()
# Out:
#  Choose 1:shape
#  Choose 2:columns
#  Choose 3:data types
#  Choose 4:index
#  Choose 5:describe4
# The DataFrame is currently using this as index
#
#  Int64Index([  3738,   3739,   3740,   3741,   3742,   3743,   3744,   3745,
#               3746,   3747,
#             ...
#             104081, 104085, 104117, 104138, 104139, 104142, 104145, 104147,
#             104216, 104219],
#            dtype='int64', length=56707)
# Yes, you got the summary!

# %%
checking()
# Out:
#  Choose 1:shape
#  Choose 2:columns
#  Choose 3:data types
#  Choose 4:index
#  Choose 5:describelp
# Please enter number from 1 to 5
#  Choose 1:shape
#  Choose 2:columns
#  Choose 3:data types
#  Choose 4:index
#  Choose 5:describe5
# These are the summary of the DataFrame
#
#          is_canceled     lead_time  arrival_date_year  \
# count  56707.000000  56707.000000            56707.0
# mean       0.358633    102.870369             2016.0
# std        0.479603    106.582358                0.0
# min        0.000000      0.000000             2016.0
# 25%        0.000000     17.000000             2016.0
# 50%        0.000000     68.000000             2016.0
# 75%        1.000000    160.000000             2016.0
# max        1.000000    709.000000             2016.0
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              56707.000000               56707.000000
# mean                  28.458162                  15.911104
# ...

# %%
hotel_2016.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                             272
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
hotel_2016['country'].fillna("Unknown" , inplace=True)
#fill in the null value with str Unknown
# Out:
# C:\Users\Acer pc\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
hotel_2016['agent'].fillna("No Agent" , inplace=True)
#fill in the null value with str No Agent

# %%
hotel_2016.isnull().sum()
# check whether there is still null value in the dataframe
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                               0
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %% [markdown]
# These are functions without class. There are certain operation that have been put into the functions.<br>
# Functions like *checking()*, *indexing()*, *drop_ren()*, are to make things easier without putting the command multiple times.<br>
# The user can only key-in the function and enter the required information so that it displays the data.

# %%
# unique(), nunique()
def counting(which_column):
    counting = hotel_2016[which_column].nunique()
    what_is = hotel_2016[which_column].unique()
    print (" There are ",counting," object of ",which_column)
    print (" These are the list of ",which_column,what_is)

# creating index and resetting index
def indexing():
    input1 = int(input(" Enter 1 for set index\n Enter 2 for reset index "))
    if input1 == 1:
        input2 = str(input(" enter new index "))
        hotel_2016.set_index(input2,inplace=True)
    if input1 ==2:
        hotel_2016.reset_index(inplace=True)
    else : 
        return
    return hotel_2016

# drop and rename the dataframe
def drop_ren():
    user_in = int(input("Enter 1:drop \n Enter 2:Rename\n"))
    if user_in == 1:
        unwanted_column = str(input(" Enter column to be drop "))
        hotel_2016.drop(unwanted_column,inplace = True,axis=1)
    if user_in == 2:
        the_col = str(input(" Enter column to be renamed "))
        new_name = str(input(" Enter new name for the column "))
        hotel_2016.rename(columns={the_col : new_name}, inplace=True)
# hotel_2016.dropna(inplace=True)
# hotel_2016.fillna(inplace=True)
    return hotel_2016

# %%
counting('country')
# Out:
#  There are  152  object of  country
#  These are the list of  country ['RUS' 'PRT' 'ARG' 'FRA' 'GBR' 'DEU' 'BRA' 'IRL' 'USA' 'KOR' 'ESP' 'DNK'
#  'CHN' 'NLD' 'HUN' 'Unknown' 'POL' 'CN' 'BEL' 'LUX' 'AUT' 'CHE' 'ARE'
#  'ITA' 'FIN' 'TUN' 'NOR' 'ROU' 'JAM' 'ALB' 'AUS' 'SWE' 'HRV' 'HKG' 'IND'
#  'ISR' 'CZE' 'IRN' 'GEO' 'DZA' 'MAR' 'AND' 'TUR' 'MOZ' 'ZAF' 'GIB' 'URY'
#  'BLR' 'EST' 'LTU' 'JEY' 'CAF' 'CYP' 'GRC' 'LVA' 'COL' 'GGY' 'KWT' 'CUB'
#  'UKR' 'CMR' 'MYS' 'THA' 'NZL' 'BIH' 'MUS' 'NGA' 'COM' 'OMN' 'SUR' 'MEX'
#  'CHL' 'UGA' 'BGR' 'CIV' 'SRB' 'DOM' 'JOR' 'SYR' 'PHL' 'PRI' 'JPN' 'SGP'
#  'ARM' 'BDI' 'AGO' 'SAU' 'LBN' 'VNM' 'AZE' 'SVN' 'PLW' 'QAT' 'EGY' 'PER'
#  'SVK' 'CPV' 'MDV' 'MLT' 'MWI' 'ECU' 'VEN' 'IRQ' 'SEN' 'IDN' 'TWN' 'HND'
#  'RWA' 'PAK' 'ZMB' 'KHM' 'MCO' 'BGD' 'ISL' 'UZB' 'KAZ' 'IMN' 'TJK' 'NIC'
#  'BEN' 'MAC' 'VGB' 'CRI' 'TZA' 'GAB' 'MKD' 'GHA' 'TMP' 'GLP' 'KEN' 'BFA'
#  'LKA' 'LBY' 'PAN' 'GNB' 'MLI' 'BHR' 'NAM' 'BOL' 'SYC' 'PRY' 'BRB' 'ABW'
# ...

# %%
counting('arrival_date_month')
# Out:
#  There are  12  object of  arrival_date_month
#  These are the list of  arrival_date_month ['January' 'February' 'March' 'April' 'May' 'June' 'July' 'August'
#  'September' 'October' 'November' 'December']

# %%
indexing()
# Out:
#  Enter 1 for set index
#  Enter 2 for reset index 1
#  enter new index hotel

# %%
hotel_2016
# Out:
#               is_canceled  lead_time  arrival_date_year arrival_date_month  \
# hotel
# Resort Hotel            0        109               2016            January
# Resort Hotel            0        109               2016            January
# Resort Hotel            1          2               2016            January
# Resort Hotel            0         88               2016            January
# Resort Hotel            1         20               2016            January
# ...                   ...        ...                ...                ...
# City Hotel              0         17               2016           December
# City Hotel              0        177               2016           December
# City Hotel              0        107               2016           December
# City Hotel              0        310               2016           December
# City Hotel              0        310               2016           December
#
# ...

# %%
indexing()
# Out:
#  Enter 1 for set index
#  Enter 2 for reset index 2
#                       name         hotel  is_canceled  lead_time  \
# 0             Sherri Ortiz  Resort Hotel            0        109
# 1               John Patel  Resort Hotel            0        109
# 2           Ashley Stewart  Resort Hotel            1          2
# 3           Vanessa Taylor  Resort Hotel            0         88
# 4              Erik Jordan  Resort Hotel            1         20
# ...                    ...           ...          ...        ...
# 56702         Billy Howell    City Hotel            0         17
# 56703          Mark Torres    City Hotel            0        177
# 56704  Elizabeth Davenport    City Hotel            0        107
# 56705     Daniel Patterson    City Hotel            0        310
# 56706       Carolyn Peters    City Hotel            0        310
#
#        arrival_date_year arrival_date_month  arrival_date_week_number  \
# ...

# %%
indexing()
# Out:
#  Enter 1 for set index
#  Enter 2 for reset index 2
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        109               2016
# 1      Resort Hotel            0        109               2016
# 2      Resort Hotel            1          2               2016
# 3      Resort Hotel            0         88               2016
# 4      Resort Hotel            1         20               2016
# ...             ...          ...        ...                ...
# 56702    City Hotel            0         17               2016
# 56703    City Hotel            0        177               2016
# 56704    City Hotel            0        107               2016
# 56705    City Hotel            0        310               2016
# 56706    City Hotel            0        310               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
drop_ren()
# Out:
# Enter 1:drop
#  Enter 2:Rename
# 2
#  Enter column to be renamed agent
#  Enter new name for the column agent_id
# C:\Users\Acer pc\anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        109               2016
# 1      Resort Hotel            0        109               2016
# 2      Resort Hotel            1          2               2016
# 3      Resort Hotel            0         88               2016
# 4      Resort Hotel            1         20               2016
# ...             ...          ...        ...                ...
# 56702    City Hotel            0         17               2016
# ...

# %%
drop_ren()
# Out:
# Enter 1:drop
#  Enter 2:Rename
# 1
#  Enter column to be drop company
# C:\Users\Acer pc\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        109               2016
# 1      Resort Hotel            0        109               2016
# 2      Resort Hotel            1          2               2016
# 3      Resort Hotel            0         88               2016
# 4      Resort Hotel            1         20               2016
# ...             ...          ...        ...                ...
# 56702    City Hotel            0         17               2016
# 56703    City Hotel            0        177               2016
# ...

# %% [markdown]
# >CLASS AND FUNCTION <br>
# ---
# Naming the class as *table* with functions in it as methods and variables for filtering the dataframe. <br>
# By using the functions we can specifically filtered desired column with specific rows that we want. <br>
# Inside this class, there is also a function to display the count for choosen column using the **value_counts()** operation.

# %%
class table:  
# this class is function to filtering
    def __init__ (self, user_table) :
        self.user_table = user_table
        print(self.user_table)
        
    # produce table visual    
    def table_class(self):
        self.hotel_2016 = hotel_2016
        self.user_table = self.hotel_2016
        return self.user_table
    # filter specific column
    def get_column(self,the_col):
        self.the_col = the_col
        return self.user_table[self.the_col]
    # filter specific rows based on the column : the_col
    def rows_in_column(self,x_1=1,x_2=1):
        self.x_1 = x_1
        self.x_2 = x_2
        return self.user_table[self.the_col].iloc[x_1:x_2]
    #def get_info(self,list_of_column,the_object,observe):        
        #return self.user_table[self.user_table[self.the_col] == the_object][observe]
    def value_to_count(self):
        return self.user_table[self.the_col].value_counts()
    def sorting_value(self):
        return self.user_table.sort_values(by = self.the_col,ascending = False)
    #filtering with columns and specific object in the column
    def get_info(self,the_object):    
        list_observe = []
        observe = ''
        while observe != 'quit':
            observe = input( "enter column to refer to... ")
            if observe !='quit':
                list_observe.append(observe)
                return self.user_table[self.user_table[self.the_col] == the_object][[observe]]
            # try to do multiple for the column "observe" but cant work and dont know why
            if observe == 'quit':
                return self.user_table[self.user_table[self.the_col] == the_object]
            
    #function to inspect certain range of column in a table       
    def get_cord(self, x1=1,x2=1,x3=1,x4=1):
        self.x1 = x1
        self.x2 = x2
        self.x3 = x3
        self.x4 = x4
        return self.user_table.iloc[x1:x2,x3:x4]
    
    # function to compare between desired columns
    def try_column(self):
        list_of_column = []
        #self.list_of_column = list_of_column
        the_column = ''
        #self.the_column = the_column
        while the_column != 'quit':
            the_column = input("Please enter the column, or enter 'quit': ")
            if the_column != 'quit':
                list_of_column.append(the_column)
        # Show that the name has been added to the list.
        return self.user_table[list_of_column]

# %%
table1 = table('data1')
table1.table_class()
table1.get_column('name')
table1.value_to_count()
table1.sorting_value()
#table1.table_class()
table1.get_info('Mary Morales')
# Out:
# data1
# enter column to refer to... country
#       country
# 55470     IRL

# %%
table1.try_column()
# Out:
# Please enter the column, or enter 'quit': name
# Please enter the column, or enter 'quit': reservation_status
# Please enter the column, or enter 'quit': meal
# Please enter the column, or enter 'quit': quit
#                       name reservation_status meal
# 0             Sherri Ortiz          Check-Out   BB
# 1               John Patel          Check-Out   BB
# 2           Ashley Stewart            No-Show   BB
# 3           Vanessa Taylor          Check-Out   HB
# 4              Erik Jordan           Canceled   BB
# ...                    ...                ...  ...
# 56702         Billy Howell          Check-Out   SC
# 56703          Mark Torres          Check-Out   BB
# 56704  Elizabeth Davenport          Check-Out   BB
# 56705     Daniel Patterson          Check-Out   SC
# 56706       Carolyn Peters          Check-Out   SC
#
# [56707 rows x 3 columns]

# %%
table1.get_cord(0,5,1,10)
# Out:
#    is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0            0        109               2016            January
# 1            0        109               2016            January
# 2            1          2               2016            January
# 3            0         88               2016            January
# 4            1         20               2016            January
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                         1                          1
# 1                         1                          1
# 2                         1                          1
# 3                         1                          1
# 4                         1                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults
# 0                        0                     1       2
# 1                        0                     1       2
# 2                        0                     1       2
# ...

# %% [markdown]
# >APPLY<br>
# ---
# Using *apply*, for the dataframe. In this case we're going to change the *float* value to *int* value.<br>
# The column will to be changed is *children*. Initally, this column is float, therefore to change it to int,<br>
# we use *apply*.

# %% [markdown]
# Due to *children* consist of NaN value, we use fillna to neturalize the value.

# %%
hotel_2016["children"].fillna(0.0, inplace = True)
# replacing the value of null value with 0.0 float
# Out:
# C:\Users\Acer pc\anaconda3\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
hotel_2016['children'] = hotel_2016['children'].apply(lambda x: int(x)) # change the dtype
hotel_2016['children']
# Out:
# <ipython-input-31-046b889326e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_2016['children'] = hotel_2016['children'].apply(lambda x: int(x))
# 0        0
# 1        2
# 2        0
# 3        0
# 4        2
#         ..
# 56702    0
# 56703    0
# 56704    0
# 56705    0
# 56706    0
# Name: children, Length: 56707, dtype: int64

# %%
#There are 333 total of agents
hotel_2016['agent_id'].nunique()
# Out:
# 248

# %%
#hotel_2016["agent"].fillna("No agent", inplace = True)
hotel_2016['agent_id'].head(20)
# Out:
# 0     240.0
# 1     240.0
# 2     240.0
# 3     241.0
# 4     240.0
# 5     240.0
# 6     241.0
# 7     305.0
# 8     305.0
# 9     305.0
# 10    305.0
# 11    305.0
# 12    305.0
# 13    305.0
# 14    305.0
# 15    305.0
# 16    305.0
# 17    305.0
# 18    305.0
# 19    305.0
# Name: agent_id, dtype: object

# %% [markdown]
# **Mapping/Renaming**<br>
# Mapping can be used to change the name for the items in column using dictionary.

# %%
hotel_test = hotel_2016['market_segment'].map({'Offline TA/TO':'Offline TO'})
hotel_test.value_counts()
# Out:
# Offline TO    12473
# Name: market_segment, dtype: int64

# %%
def renaming_repeat(new_name1):
    dict_cancel={1:"Yes",0:"No"}
    return dict_cancel[new_name1]

# %%
hotel_2016['is_repeated_guest']=hotel_2016['is_repeated_guest'].apply(renaming_repeat)
# Out:
# <ipython-input-41-8c00a8abd659>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_2016['is_repeated_guest']=hotel_2016['is_repeated_guest'].apply(renaming_repeat)

# %%
hotel_2016['is_repeated_guest'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
hotel_2016['is_repeated_guest'].value_counts().unique()
# Out:
# array([54929,  1778], dtype=int64)

# %%
def renaming_meal(new_name):
    dict_meal={"BB":"Bed Breakfast","FB":"Full Breakfast","HB":"Half Breakfast","SC":"Special Meal","Undefined":"No meal"}
    return dict_meal[new_name]

# %%
hotel_2016['meal']=hotel_2016['meal'].apply(renaming_meal)
# Out:
# <ipython-input-45-e05a1e229916>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_2016['meal']=hotel_2016['meal'].apply(renaming_meal)

# %%
hotel_2016['meal'].unique()
# Out:
# array(['Bed Breakfast', 'Half Breakfast', 'No meal', 'Full Breakfast',
#        'Special Meal'], dtype=object)

# %% [markdown]
# **Adding Column**<br>
# The numbers in columns *children*,*adults* and *babies* will be total up to get the total number of guest.

# %%
hotel_2016['total_guest']=hotel_2016['adults']+hotel_2016['children']+hotel_2016['babies']
# Out:
# <ipython-input-47-799f879e027f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_2016['total_guest']=hotel_2016['adults']+hotel_2016['children']+hotel_2016['babies']

# %%
hotel_2016
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        109               2016
# 1      Resort Hotel            0        109               2016
# 2      Resort Hotel            1          2               2016
# 3      Resort Hotel            0         88               2016
# 4      Resort Hotel            1         20               2016
# ...             ...          ...        ...                ...
# 56702    City Hotel            0         17               2016
# 56703    City Hotel            0        177               2016
# 56704    City Hotel            0        107               2016
# 56705    City Hotel            0        310               2016
# 56706    City Hotel            0        310               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                January                         1                          1
# ...

# %% [markdown]
# Producing dictionary from the dataset.

# %%
# Assign for only 10 first rows because to avoid the infinite values
hotel_name = hotel['name'].head(10)
hotel_name = hotel_name.to_dict()

# %%
hotel_name
# Out:
# {0: 'Ernest Barnes',
#  1: 'Andrea Baker',
#  2: 'Rebecca Parker',
#  3: 'Laura Murray',
#  4: 'Linda Hines',
#  5: 'Jasmine Fletcher',
#  6: 'Dylan Rangel',
#  7: 'William Velez',
#  8: 'Steven Murphy',
#  9: 'Michael Moore'}

# %%
#hotel.set_index('name',inplace=True)
# index can be replaced by the assigned index and produce different output depends in the index

# %%
# observe the top 6 customer that attend to the hotel , therefore use head(6)
hotel_vip_invitation = hotel_2016['name'].value_counts().head(6)
hotel_vip_invitation = hotel_vip_invitation.to_dict()

# %%
hotel_vip_invitation
# Out:
# {'Robert Smith': 27,
#  'John Smith': 25,
#  'Michael Johnson': 24,
#  'Christopher Smith': 23,
#  'Michael Smith': 21,
#  'David Smith': 21}

# %% [markdown]
# **Kwargs**<br>
# Using ****kwargs** to call specific count of dictionary from specific column.

# %%
# the function is to produce the dictionary from hotel_name
def print_name_kwargs(**kwargs):
    for keyword,value in hotel_name.items():
        print(keyword, ":",value) 
print_name_kwargs()
# Out:
# 0 : Ernest Barnes
# 1 : Andrea Baker
# 2 : Rebecca Parker
# 3 : Laura Murray
# 4 : Linda Hines
# 5 : Jasmine Fletcher
# 6 : Dylan Rangel
# 7 : William Velez
# 8 : Steven Murphy
# 9 : Michael Moore

# %%
def print_name_kwargs(**kwargs):
    for keyword,value in hotel_vip_invitation.items():
        print(keyword, ":",value) 
print_name_kwargs()
# Out:
# Robert Smith : 27
# John Smith : 25
# Michael Johnson : 24
# Christopher Smith : 23
# Michael Smith : 21
# David Smith : 21

# %% [markdown]
# Extra command in **PANDAS** ..

# %%
hotel_2016.groupby(by=['name','country'])['reservation_status'].max()
#hotel_2016.groupby(by=['name','arrival_date_month'])['name'].agg(['count','mean','min','max'])
# Out:
# name             country
# Aaron Acevedo    ITA        Check-Out
# Aaron Acosta     PRT         Canceled
# Aaron Adams      CN         Check-Out
#                  DEU        Check-Out
# Aaron Alexander  DEU        Check-Out
#                               ...
# Zoe Haley        PRT         Canceled
# Zoe Hancock      NLD         Canceled
# Zoe Henderson    PRT        Check-Out
# Zoe Simpson      PRT        Check-Out
# Zoe Wu           PRT        Check-Out
# Name: reservation_status, Length: 53463, dtype: object

# %%
#hotel_2016.groupby(by=['name','country'])['reservation_status'].iloc[324:340]

# %%
hotel_2016.groupby(by=['name','country']).count().iloc[345:360]
# Out:
#                         hotel  is_canceled  lead_time  arrival_date_year  \
# name           country
# Adam Nash MD   AUS          1            1          1                  1
# Adam Nelson    PRT          1            1          1                  1
# Adam Nguyen    PRT          1            1          1                  1
# Adam Nunez     GBR          1            1          1                  1
# Adam Obrien    PRT          1            1          1                  1
# Adam Ortiz     PRT          2            2          2                  2
# Adam Page      PRT          2            2          2                  2
# Adam Parker    PRT          1            1          1                  1
# Adam Patterson SRB          1            1          1                  1
# Adam Perez     GBR          1            1          1                  1
# Adam Peterson  BRA          1            1          1                  1
# ...

# %%
# how many people have come to the hotel multiple times
hotel['name'].duplicated().value_counts()
# Out:
# False    81503
# True     37887
# Name: name, dtype: int64

# %%
hotel['country'].duplicated().value_counts()
# Out:
# True     119212
# False       178
# Name: country, dtype: int64

# %% [markdown]
# ##### Visualising <br>
# In this section, it presents the plotting of pandas. <br>
# Every plot has been made according to the suitable information given. <br>
# Each plot gives different output thus making sure it's suitable to use is very crucial otherwise it wont give <br>
# the desired output.<br>
# It will result in no data can be read or compared to.

# %%
print( " The plot is showing the type of reservation_status for hotel booking ")
hotel_2016['reservation_status'].value_counts().sort_index().plot(kind='bar')
plt.title('Bar chart on resercation status of hotel booking')
plt.xlabel('Reservation Status')
plt.ylabel('Values')
# Out:
#  The plot is showing the type of reservation_status for hotel booking
# Text(0, 0.5, 'Values')

# %%
print( " The pie chart is showing the type of customer, therefore the comparison between \n type of customer can be observed.")
hotel_2016['meal'].value_counts().plot(kind = 'pie',figsize=(14,14),autopct='%1.1f%%')
plt.title('Pie Chart of percentage of customer type that attend the hotel')
plt.legend()
# Out:
#  The pie chart is showing the type of customer, therefore the comparison between
#  type of customer can be observed.

# %%
print( " The pie chart is showing the type of customer, therefore the comparison between \n type of customer can be observed.")
hotel_2016['customer_type'].value_counts().plot(kind = 'pie',figsize=(14,14),autopct='%1.1f%%')
plt.title('Pie Chart of percentage of customer type that attend the hotel')
plt.legend()
# Out:
#  The pie chart is showing the type of customer, therefore the comparison between
#  type of customer can be observed.

# %%
hotel['market_segment'].value_counts().plot(kind='bar',x ='market_segment')
plt.title('The Comparison between market segment used for marketing')
plt.xlabel('Market Segment')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')
